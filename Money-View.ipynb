# %%
import pandas as pd
import warnings
import numpy as np
from sqlalchemy import create_engine, Table, MetaData
import urllib.parse
from datetime import datetime
from sqlalchemy.sql import text
import re
import json
import pyodbc
import warnings
import requests
warnings.filterwarnings("ignore")
import requests
import msal
from datetime import datetime, timezone
from apscheduler.schedulers.blocking import BlockingScheduler
import base64
import os
import pandas as pd
import pyodbc
from io import BytesIO
from sqlalchemy import create_engine
from sqlalchemy.sql import text
import urllib
import logging
import warnings
import json
from apscheduler.events import EVENT_JOB_ERROR

def job_error_listener(event):
    print(f"Job {event.job_id} failed with exception: {event.exception}")

import json
import requests

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)  
pd.set_option('display.width', 1000)  
pd.set_option('display.colheader_justify', 'center')
pd.set_option('display.float_format', '{:,.0f}'.format) 



username = 'Vaibhav'
password = 'D@taBa$eCreD@2520'
server = '172.16.1.13'
database = 'Ops_Analytics'
quoted_password = urllib.parse.quote_plus(password)
connection_string = f'mssql+pyodbc://{username}:{quoted_password}@{server}/{database}?driver=ODBC Driver 17 for SQL Server'
conn = create_engine(connection_string)

try:
    with conn.connect() as connection:
        print("Connection successful!")
except Exception as e:
    print("Connection failed:", e)

today_date = datetime.now().strftime('%Y-%m-%d')

print("Fetching data from DB")

def Dialer_allocation(df, lead_id, action):
    url = f"https://api-smartflo.tatateleservices.com/v1/broadcast/leads/{lead_id}"
    print(url)
    headers = {
        "Authorization": "Bearer eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJzdWIiOiI1NTE1ODciLCJjciI6dHJ1ZSwiaXNzIjoiaHR0cHM6Ly9jbG91ZHBob25lLnRhdGF0ZWxlc2VydmljZXMuY29tL3Rva2VuL2dlbmVyYXRlIiwiaWF0IjoxNzQzODQzMzExLCJleHAiOjIwNDM4NDMzMTEsIm5iZiI6MTc0Mzg0MzMxMSwianRpIjoiSURsdmRjWlhSclJ2OE5VdSJ9.CxhPy9NXVr4VW15dLjcNa_1YW83CH90NVGuzltgJA1U",
        "accept": "application/json",
        "content-type": "application/json"
    }
        
    # Convert DataFrame to required format
    converted_data = {
        "data": df.apply(
            lambda x: {
                "field_0": x['Phone Number'],
                "field_1": x["Name"],
                "field_3": x['Lead id'],
                "field_4": x['stage'],
            }, axis=1
        ).tolist(),
        "duplicate_option": f"{action}"
    }

    print(converted_data)
    # Convert to JSON format
    json_output = json.dumps(converted_data, indent=4)
        
    # Send POST request with JSON data/
    response = requests.post(url, headers=headers, json=converted_data)
    print(f"Status: {response.status_code}, Response: {response.json()}")

    return  json_output


def delete_dialer(delete_number, lead_id):
    url = f"https://api-smartflo.tatateleservices.com/v1/broadcast/leads/{lead_id}"

    print(url)
    payload = {
        "field": "field_0",
        "data": delete_number
    }
    print(payload)

    headers = {
        "accept": "application/json",
        "Authorization": "Bearer eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJzdWIiOiI1NTE1ODciLCJjciI6dHJ1ZSwiaXNzIjoiaHR0cHM6Ly9jbG91ZHBob25lLnRhdGF0ZWxlc2VydmljZXMuY29tL3Rva2VuL2dlbmVyYXRlIiwiaWF0IjoxNzQzODQzMzExLCJleHAiOjIwNDM4NDMzMTEsIm5iZiI6MTc0Mzg0MzMxMSwianRpIjoiSURsdmRjWlhSclJ2OE5VdSJ9.CxhPy9NXVr4VW15dLjcNa_1YW83CH90NVGuzltgJA1U",
        "content-type": "application/json"
    }

    try:
        response = requests.delete(url, json=payload, headers=headers)
        
        # Check if the response is successful
        if response.status_code == 200:
            print("✅ Deletion Successful!")
            print("Response:", json.dumps(response.json(), indent=4))
        else:
            print(f"❌ Failed! Status Code: {response.status_code}")
            print("Error Response:", response.text)

    except requests.exceptions.RequestException as e:
        print("⚠️ API Request Error:", e)
# Out:
# Connection successful!
# Fetching data from DB

# %%
  

#           Allocation logic

df_CS = pd.read_excel(r"C:\Users\kunal.sharma\Documents\wc_mv_mis.xlsx")
df_CS['date_created'] = pd.to_datetime(df_CS['date_created'], errors='coerce')
df_CS = df_CS.sort_values(by="date_created", ascending=False)
df_CS = df_CS.drop_duplicates(subset="phone_number", keep="first")
df_allocation = df_CS
df_allocation["date_created"] = pd.to_datetime(df_CS["date_created"], errors="coerce")
today = pd.Timestamp.today().normalize()
thirty_days_ago = today - pd.Timedelta(days=30)
df_allocation = df_allocation[df_allocation["date_created"] >= thirty_days_ago]
print("30days")
statuses = [
    "2. Offer not selected", "3. KYC Pending", "4. Selfie Pending",
    "5. IMPS Pending", "6. Submit Pending", "7. Waiting for document upload",
    "8. NACH Pending", "9. Agreement Pending"
]
df_allocation = df_allocation[df_allocation["current_status"].isin(statuses)]
Seg = [
    "Near_Prime","Prime","Super_Prime"
]
df_allocation = df_allocation[df_allocation["user_segment"].isin(Seg)]






import pyodbc
import warnings
import pandas as pd
username = 'prashant'
password = 'CredEnt!@L@2025!$'
server = '172.16.1.13'
database = 'Ops_Analytics'
driver = 'ODBC Driver 17 for SQL Server'

conn_str = (
    f"DRIVER={{{driver}}};"
    f"SERVER={server};"
    f"DATABASE={database};"
    f"UID={username};"
    f"PWD={password};"
    f"Trusted_Connection=no;"
)


#           Black listed number 

insert_query2 = """
    select * from Marketing.dbo.blacklist_data
"""

warnings.filterwarnings("ignore")
conn = pyodbc.connect(conn_str)
df_Indus = pd.read_sql(insert_query2, conn)

conn.close()

df_blacklist_data = df_Indus["mobile"]
df_allocation["phone_number"] = df_allocation["phone_number"].astype(str)
df_blacklist_data = df_blacklist_data.astype(str)
df_allocation_filtered = df_allocation[~df_allocation["phone_number"].isin(df_blacklist_data)]

statuses = [
    "2. Offer not selected", "3. KYC Pending", "4. Selfie Pending",
    "5. IMPS Pending", "6. Submit Pending", "7. Waiting for document upload",
    "8. NACH Pending", "9. Agreement Pending"
]
df_app = df_allocation_filtered[df_allocation_filtered["current_status"].isin(statuses)]
df_app = df_app[df_app["app_download_date"].isnull()]
# print(df_app)

# df_app = df_app["app_download_date"].isin("null")
statuses = [
    "2. Offer not selected", "3. KYC Pending", "4. Selfie Pending",
    "5. IMPS Pending", "6. Submit Pending", "7. Waiting for document upload",
    "8. NACH Pending", "9. Agreement Pending"
]

df_dis = df_allocation_filtered[df_allocation_filtered["current_status"].isin(statuses)]
df_dis = df_dis[df_dis["app_download_date"].notnull()]
print(df_dis)


df_allapp = pd.DataFrame()
df_allapp['Phone Number'] = df_app['phone_number']
df_allapp['Name'] = "Unknown"
df_allapp['Lead id'] = df_app["lead_id"]
df_allapp['stage'] = df_app["current_status"]
df_allapp = df_allapp.fillna("None")
leadid = 525260
type= "overwrite"
df_allapp = df_allapp.fillna("")
print(df_allapp)

df_alldis = pd.DataFrame()
df_alldis['Phone Number'] = df_dis['phone_number']
df_alldis['Name'] = "Unknown"
df_alldis['Lead id'] = df_dis["lead_id"]
df_alldis['stage'] = df_dis["current_status"]
df_alldis = df_alldis.fillna("None")
leadid = 525260
type= "overwrite"
df_alldis = df_alldis.fillna("")
print(df_alldis)
df_allapp.to_excel("app.xlsx", index=False)
df_alldis.to_excel("dis.xlsx", index=False)
#           Dellition logic
df_test = df_CS

df_test = df_test.sort_values(by="date_created", ascending=False)
df_test = df_test.drop_duplicates(subset="phone_number", keep="first")

df_rej = df_test[df_test["current_status"].isin(["Pre-Submit Rejected", "Cancelled", "Post-Submit Rejected", "1. Created"])]
today = pd.Timestamp.today().normalize()
thirty_days_ago = today - pd.Timedelta(days=30)
df_except_30 = df_test[df_test["date_created"] < thirty_days_ago]
df_rej["phone_number"] = df_rej["phone_number"].astype(str)
df_rej["phone_number"] = '+91' + df_rej["phone_number"]
delete_data = df_rej["phone_number"].tolist()
print(delete_data)
df_rej.to_excel("deleted.xlsx", index=False)
df_except_30.to_excel("deleted30.xlsx", index=False)
batch_size = 50000
for i in range(0, len(delete_data), batch_size):
    batch = delete_data[i:i + batch_size]
    # print(delete_data)
    delete_dialer(batch,525260)
    delete_dialer(batch,602955)
    delete_dialer(batch,611853)
    
df_except_30["phone_number"] = df_except_30["phone_number"].astype(str)
df_except_30["phone_number"] = '+91' + df_except_30["phone_number"]
delete_data = df_except_30["phone_number"].tolist()
for i in range(0, len(delete_data), batch_size):
    batch = delete_data[i:i + batch_size]
    # print(delete_data)
    delete_dialer(batch,525260)
    delete_dialer(batch,602955)
    delete_dialer(batch,611853)
# Out:
# 30days
#        date_created date_modified              lead_id               loan_application_no user_segment employment_type     current_status      max_loan_amount_eligible  applied_amount  rate_of_interest  processing_fee  tenure  disbursed_amt disbursal_date cancellation_type app_download_date  app_downloaded_history partner_ref_id reject_reason phone_number customer_type
# 198815  2025-07-10    2025-07-10   2c9fa01097f055a20197f1a9d0d01f85     206127958159      Near_Prime         Salaried        8. NACH Pending            75000                75000             30              4337         12          0            NaT               NaN           2025-07-10                1              WeCredit          NaN      7894202247        New
# ...

# %%
import requests
import msal
from datetime import datetime, timezone
from apscheduler.schedulers.blocking import BlockingScheduler
import base64
import os
import pandas as pd
import pyodbc
from io import BytesIO
from sqlalchemy import create_engine, text
import urllib
import logging
import warnings
import schedule
import time
import json
from sqlalchemy import types
username = 'prashant'
password = 'CredEnt!@L@2025!$'
server = '172.16.1.13'
database = 'RUNO'
driver = 'ODBC Driver 17 for SQL Server'
 
quoted_password = urllib.parse.quote_plus(password)
conn_str = f"mssql+pyodbc://{username}:{quoted_password}@{server}/{database}?driver=ODBC+Driver+17+for+SQL+Server"
engine = create_engine(connection_string)
conn = create_engine(connection_string)
 
today = datetime.now(timezone.utc).strftime("%Y-%m-%dT00:00:00Z")

    
insert_query2 = """
    WITH Ranked_CDR AS (
        SELECT *,
            ROW_NUMBER() OVER (PARTITION BY a.Client_Number ORDER BY a.end_stamp DESC) AS rn,
            datediff(day,try_cast(end_stamp as date),try_cast(getdate() as date)) as diff
        FROM RUNO.dbo.Dialer_CDR_report a WITH (NOLOCK)
        WHERE campaign_name IN ('Moneyview dis','money view repeat')
        AND Disposition_Name IN ('Final Not Interested', 'Follow Up', 'App Start', 'Interested')
        AND TRY_CAST(end_stamp AS DATE) >= DATEADD(DAY, -30, CAST(GETDATE() AS DATE))
    )
    SELECT *
    FROM Ranked_CDR
    WHERE rn = 1
    and diff > 2
"""

warnings.filterwarnings("ignore")
# conn = pyodbc.connect(conn_str)
df_del = pd.read_sql(insert_query2, conn)
#           Schedule shuffle       

df_deletion = df_del[
    (df_del["Disposition_Name"].isin(["Follow Up", "App Start", "Interested"])) &
    (df_del["diff"] > 2)
]
print(df_deletion)
# df_deletion["phone_number"] = df_deletion["phone_number"].astype(str)
# df_deletion["phone_number"] = '+91' + df_deletion["phone_number"]
delete_data = df_deletion["Client_Number"].tolist()
batch_size = 50000
for i in range(0, len(delete_data), batch_size):
    batch = delete_data[i:i + batch_size]
    # delete_dialer(batch,525260)
    delete_dialer(batch,611853)
    delete_dialer(batch,602955)
    
#           FNI

if datetime.datetime.today().weekday() == 2:
    df_FNI = df_del[df_del["Disposition_Name"] == "Final Not Interested"]
    delete_data = df_FNI
    batch_size = 50000
    for i in range(0, len(delete_data), batch_size):
        batch = delete_data[i:i + batch_size]
        delete_dialer(batch,611853)
        delete_dialer(batch,602955)
    print("df_FNI created for Monday only")
else:
    df_FNI = pd.DataFrame()  # Empty DataFrame if not Monday
    print("Today is not Monday, df_FNI is empty")



        #   CDR PULLING

insert_query2 = """
    WITH Ranked_CDR AS (
        SELECT 
            *,
            ROW_NUMBER() OVER (PARTITION BY a.Client_Number ORDER BY a.end_stamp DESC) AS rn,
            datediff(day,try_cast(end_stamp as date),try_cast(getdate() as date)) as diff
        FROM RUNO.dbo.Dialer_CDR_report a WITH (NOLOCK)
        WHERE campaign_name IN ('Moneyview')
        AND Disposition_Name IN ('Follow Up', 'App Start', 'Interested')
        AND TRY_CAST(end_stamp AS DATE) >= DATEADD(DAY, -30, CAST(GETDATE() AS DATE))
    )
    SELECT *
    FROM Ranked_CDR
    WHERE rn = 1;
    and datediff > 2
"""

warnings.filterwarnings("ignore")
conn = pyodbc.connect(conn_str)
df_del = pd.read_sql(insert_query2, conn)


# #           Schedule shuffle       

df_deletion = df_del[
    (df_del["Disposition_Name"].isin(["Follow Up", "App Start", "Interested"])) &
    (df_del["diff"] >= 3)
]
print(df_deletion)
# df_deletion["phone_number"] = df_deletion["phone_number"].astype(str)
# df_deletion["phone_number"] = '+91' + df_deletion["phone_number"]
delete_data = df_deletion["Client_Number"].tolist()
for i in range(0, len(delete_data), batch_size):
    batch = delete_data[i:i + batch_size]
    delete_dialer(batch,525260)
    
    

df_allocations= df_CS
df_allocations = df_allocations.sort_values(by="date_created", ascending=False)
df_allocations = df_allocations.drop_duplicates(subset="phone_number", keep="first")
df_allocations["date_created"] = pd.to_datetime(df_CS["date_created"], errors="coerce")
today = pd.Timestamp.today().normalize()
thirty_days_ago = today - pd.Timedelta(days=30)
df_allocations = df_allocations[df_allocations["date_created"] >= thirty_days_ago]
print("30days")
statuses = [
    "2. Offer not selected", "3. KYC Pending", "4. Selfie Pending",
    "5. IMPS Pending", "6. Submit Pending", "7. Waiting for document upload",
    "8. NACH Pending", "9. Agreement Pending"
]
df_allocations = df_allocations[df_allocations["current_status"].isin(statuses)]
Seg = [
    "Sub_Prime"
]
df_allocations = df_allocations[df_allocations["user_segment"].isin(Seg)]


Seg = [
    "Repeat"
]
df_allocations = df_allocations[df_allocations["customer_type"].isin(Seg)]



import pyodbc
import warnings
import pandas as pd
username = 'prashant'
password = 'CredEnt!@L@2025!$'
server = '172.16.1.13'
database = 'Ops_Analytics'
driver = 'ODBC Driver 17 for SQL Server'

conn_str = (
    f"DRIVER={{{driver}}};"
    f"SERVER={server};"
    f"DATABASE={database};"
    f"UID={username};"
    f"PWD={password};"
    f"Trusted_Connection=no;"
)


#           Black listed number 

insert_query2 = """
    select * from Marketing.dbo.blacklist_data
"""

warnings.filterwarnings("ignore")
conn = pyodbc.connect(conn_str)
df_Indus = pd.read_sql(insert_query2, conn)

conn.close()

df_blacklist_data = df_Indus["mobile"]
df_allocations["phone_number"] = df_allocations["phone_number"].astype(str)
df_blacklist_data = df_blacklist_data.astype(str)
df_allocation_filtered1 = df_allocations[~df_allocations["phone_number"].isin(df_blacklist_data)]

df_repeat=df_allocation_filtered1
# print(df)
df_repeat.to_excel("repat.xlsx", index=False)
# df_app.to_excel("app.xlsx", index=False)
# df_dis.to_excel("dis.xlsx", index=False)

#     Allocation

df_allapp["Phone Number"] = df_allapp["Phone Number"].astype(int)
df_alldis["Phone Number"] = df_alldis["Phone Number"].astype(int)
df_repeat["Phone Number"] = df_repeat["Phone Number"].astype(int)
# # print(df_a)


Dialer_allocation(df_allapp,525260,type)
Dialer_allocation(df_repeat,602955,type)
Dialer_allocation(df_alldis,611853,type)
# Out:
#        date_created date_modified              lead_id               loan_application_no user_segment employment_type     current_status      max_loan_amount_eligible  applied_amount  rate_of_interest  processing_fee  tenure  disbursed_amt disbursal_date cancellation_type app_download_date  app_downloaded_history partner_ref_id reject_reason phone_number customer_type
# 183733  2025-07-10    2025-07-10   2c9fa01097f055a20197f178c5e9648c     202913984124       Sub_Prime      Salaried     2. Offer not selected           400000                  0               0                 0           0          0            NaT               NaN                  NaT                1              WeCredit          NaN      6387378058      Repeat
# ...

# %%
# Out:
#        date_created date_modified              lead_id               loan_application_no user_segment employment_type  current_status   max_loan_amount_eligible  applied_amount  rate_of_interest  processing_fee  tenure  disbursed_amt disbursal_date cancellation_type app_download_date  app_downloaded_history partner_ref_id reject_reason phone_number customer_type
# 146090  2025-07-09    2025-07-09   2c9fa83697ed83b30197ef4a536663df     266315926887       Near_Prime        Salaried  8. NACH Pending            10000                10000             36               546          5          0            NaT               NaN           2025-07-09                0              WeCredit          NaN      8179132843        New
# ...

# %%
import requests
import msal
from datetime import datetime, timezone
from apscheduler.schedulers.blocking import BlockingScheduler
import base64
import os
import pandas as pd
import pyodbc
from io import BytesIO
from sqlalchemy import create_engine, text
import urllib
import logging
import warnings
import schedule
import time
import json
from sqlalchemy import types
username = 'prashant'
password = 'CredEnt!@L@2025!$'
server = '172.16.1.13'
database = 'Ops_Analytics'
driver = 'ODBC Driver 17 for SQL Server'
 
quoted_password = urllib.parse.quote_plus(password)
connection_string = f"mssql+pyodbc://{username}:{quoted_password}@{server}/{database}?driver=ODBC+Driver+17+for+SQL+Server"
engine = create_engine(connection_string)
conn = create_engine(connection_string)
 
today = datetime.now(timezone.utc).strftime("%Y-%m-%dT00:00:00Z")


sql_script = """
drop table if exists #new

select cast(date_created as date) date_created,
Count(Distinct  phone_number) as journey_start,
Count(Distinct  case when   current_status not in ('1. Created','Pre-Submit Rejected') then phone_number end) as Eligible,
Count(Distinct  case when  app_download_date is not null and  current_status not in ('1. Created','Pre-Submit Rejected') then phone_number end) as App_download,
Count(Distinct case when  current_status not in ('1. Created','Cancelled','Pre-Submit Rejected','2. Offer not selected') then phone_number end) as offer_select,
Count(Distinct  case when  current_status not in ('1. Created','Cancelled','Pre-Submit Rejected','2. Offer not selected','3. KYC Pending')  then phone_number end) as KYC,
Count(Distinct  case when  current_status in ('7. Waiting for document upload','Post-Submit Rejected','8. NACH Pending','9. Agreement Pending','10. Disbursal initiated','11. Disbursed')  then phone_number end) as Submit,
Count(Distinct  case when  current_status in ('8. NACH Pending','9. agreement pending','10. Disbursal initiated','11. Disbursed') then phone_number end) as Submit_Apr,
Count(Distinct  case when  current_status in ('9. agreement pending','10. Disbursal initiated','11. Disbursed') then phone_number end) as nach_complete,
Count(Distinct case when  current_status in ('10. Disbursal initiated','11. Disbursed') then phone_number end) as LA,
Count(Distinct  case when current_status in ('11. Disbursed') then phone_number end) as disbursal,
sum ( disbursed_amt ) as disbursed_amt
into #new
from mis.[dbo].[mis_automation_mv]
where --cast(date_modified as date) >= '2025-06-01' --and day(hit_time) = 11 and month(hit_time) = 05 and year(hit_time) = 2025
CAST(hit_time as date)  = (select MAX(cast(hit_time as date)) from  mis.[dbo].[mis_automation_mv])
--and app_downloaded_history = 1 
and
customer_type ='New'
--customer_type ='Repeat'
and month(cast(date_created as date)) =7--'2025-05-01' )--or disbursal_date  is null)
and (month(disbursal_date)= 7 or disbursal_date is null)
group by  cast(date_created as date)
order by   cast(date_created as date)

	"""
 
with engine.begin() as connection:
    connection.execute(text(sql_script))
query = "select * from #new"
df_newH = pd.read_sql(query, engine)


import pandas as pd

import pandas as pd

# Suppose 'totals' is your Series of summed values (e.g., journey_start, Eligible, etc.)
totals = df_newH[['journey_start','Eligible','App_download','offer_select','KYC',
             'Submit','Submit_Apr','nach_complete','LA','disbursal','disbursed_amt']].sum()



# Convert the Series into a vertical one-column DataFrame
df_newH = totals.reset_index(drop=True).to_frame(name='New horizontal')

# print(df_vertical)

sql_script = """
drop table if exists #new
select cast(date_modified as date) date_modified,
Count(Distinct  phone_number) as journey_start,
Count(Distinct  case when   current_status not in ('1. Created','Pre-Submit Rejected') then phone_number end) as Eligible,
Count(Distinct  case when  app_download_date is not null and  current_status not in ('1. Created','Pre-Submit Rejected') then phone_number end) as App_download,
Count(Distinct case when  current_status not in ('1. Created','Cancelled','Pre-Submit Rejected','2. Offer not selected') then phone_number end) as offer_select,
Count(Distinct  case when  current_status not in ('1. Created','Cancelled','Pre-Submit Rejected','2. Offer not selected','3. KYC Pending')  then phone_number end) as KYC,
Count(Distinct  case when  current_status in ('7. Waiting for document upload','Post-Submit Rejected','8. NACH Pending','9. Agreement Pending','10. Disbursal initiated','11. Disbursed')  then phone_number end) as Submit,
Count(Distinct  case when  current_status in ('8. NACH Pending','9. agreement pending','10. Disbursal initiated','11. Disbursed') then phone_number end) as Submit_Apr,
Count(Distinct  case when  current_status in ('9. agreement pending','10. Disbursal initiated','11. Disbursed') then phone_number end) as nach_complete,
Count(Distinct case when  current_status in ('10. Disbursal initiated','11. Disbursed') then phone_number end) as LA,
Count(Distinct  case when current_status in ('11. Disbursed') then phone_number end) as disbursal,
sum ( disbursed_amt ) as disbursed_amt
into #new
from mis.[dbo].[mis_automation_mv]
where --cast(date_modified as date) >= '2025-06-01' --and day(hit_time) = 11 and month(hit_time) = 05 and year(hit_time) = 2025
CAST(hit_time as date)  = (select MAX(cast(hit_time as date)) from  mis.[dbo].[mis_automation_mv])
--and app_downloaded_history = 1 
and
customer_type ='New'
--customer_type ='Repeat'
and month(cast(date_modified as date)) =7 --'2025-05-01' )--or disbursal_date  is null)
and (month(disbursal_date)= 7 or disbursal_date is null)
group by  cast(date_modified as date)
order by   cast(date_modified as date)


	"""
 
with engine.begin() as connection:
    connection.execute(text(sql_script))
query = "select * from #new"
df_newv = pd.read_sql(query, engine)
print("new")

import pandas as pd

import pandas as pd

# Suppose 'totals' is your Series of summed values (e.g., journey_start, Eligible, etc.)
totals = df_newv[['journey_start','Eligible','App_download','offer_select','KYC',
             'Submit','Submit_Apr','nach_complete','LA','disbursal','disbursed_amt']].sum()



# Convert the Series into a vertical one-column DataFrame
df_newv = totals.reset_index(drop=True).to_frame(name='New vertical')


sql_script = """
drop table if exists #new

select cast(date_created as date) date_created,
Count(Distinct  phone_number) as journey_start,
Count(Distinct  case when   current_status not in ('1. Created','Pre-Submit Rejected') then phone_number end) as Eligible,
Count(Distinct  case when  app_download_date is not null and  current_status not in ('1. Created','Pre-Submit Rejected') then phone_number end) as App_download,
Count(Distinct case when  current_status not in ('1. Created','Cancelled','Pre-Submit Rejected','2. Offer not selected') then phone_number end) as offer_select,
Count(Distinct  case when  current_status not in ('1. Created','Cancelled','Pre-Submit Rejected','2. Offer not selected','3. KYC Pending')  then phone_number end) as KYC,
Count(Distinct  case when  current_status in ('7. Waiting for document upload','Post-Submit Rejected','8. NACH Pending','9. Agreement Pending','10. Disbursal initiated','11. Disbursed')  then phone_number end) as Submit,
Count(Distinct  case when  current_status in ('8. NACH Pending','9. agreement pending','10. Disbursal initiated','11. Disbursed') then phone_number end) as Submit_Apr,
Count(Distinct  case when  current_status in ('9. agreement pending','10. Disbursal initiated','11. Disbursed') then phone_number end) as nach_complete,
Count(Distinct case when  current_status in ('10. Disbursal initiated','11. Disbursed') then phone_number end) as LA,
Count(Distinct  case when current_status in ('11. Disbursed') then phone_number end) as disbursal,
sum ( disbursed_amt ) as disbursed_amt
into #new
from mis.[dbo].[mis_automation_mv]
where --cast(date_modified as date) >= '2025-06-01' --and day(hit_time) = 11 and month(hit_time) = 05 and year(hit_time) = 2025
CAST(hit_time as date)  = (select MAX(cast(hit_time as date)) from  mis.[dbo].[mis_automation_mv])
--and app_downloaded_history = 1 
and
--customer_type ='New'
customer_type ='Repeat'
and month(cast(date_created as date)) =7--'2025-05-01' )--or disbursal_date  is null)
and (month(disbursal_date)= 7 or disbursal_date is null)
group by  cast(date_created as date)
order by   cast(date_created as date)

	"""
 
with engine.begin() as connection:
    connection.execute(text(sql_script))
query = "select * from #new"
df_RepeatH = pd.read_sql(query, engine)


import pandas as pd

import pandas as pd

# Suppose 'totals' is your Series of summed values (e.g., journey_start, Eligible, etc.)
totals = df_RepeatH[['journey_start','Eligible','App_download','offer_select','KYC',
             'Submit','Submit_Apr','nach_complete','LA','disbursal','disbursed_amt']].sum()



# Convert the Series into a vertical one-column DataFrame
df_RepeatH = totals.reset_index(drop=True).to_frame(name='Repeat horizontal')

# print(df_vertical)

sql_script = """
drop table if exists #new
select cast(date_modified as date) date_modified,
Count(Distinct  phone_number) as journey_start,
Count(Distinct  case when   current_status not in ('1. Created','Pre-Submit Rejected') then phone_number end) as Eligible,
Count(Distinct  case when  app_download_date is not null and  current_status not in ('1. Created','Pre-Submit Rejected') then phone_number end) as App_download,
Count(Distinct case when  current_status not in ('1. Created','Cancelled','Pre-Submit Rejected','2. Offer not selected') then phone_number end) as offer_select,
Count(Distinct  case when  current_status not in ('1. Created','Cancelled','Pre-Submit Rejected','2. Offer not selected','3. KYC Pending')  then phone_number end) as KYC,
Count(Distinct  case when  current_status in ('7. Waiting for document upload','Post-Submit Rejected','8. NACH Pending','9. Agreement Pending','10. Disbursal initiated','11. Disbursed')  then phone_number end) as Submit,
Count(Distinct  case when  current_status in ('8. NACH Pending','9. agreement pending','10. Disbursal initiated','11. Disbursed') then phone_number end) as Submit_Apr,
Count(Distinct  case when  current_status in ('9. agreement pending','10. Disbursal initiated','11. Disbursed') then phone_number end) as nach_complete,
Count(Distinct case when  current_status in ('10. Disbursal initiated','11. Disbursed') then phone_number end) as LA,
Count(Distinct  case when current_status in ('11. Disbursed') then phone_number end) as disbursal,
sum ( disbursed_amt ) as disbursed_amt
into #new
from mis.[dbo].[mis_automation_mv]
where --cast(date_modified as date) >= '2025-06-01' --and day(hit_time) = 11 and month(hit_time) = 05 and year(hit_time) = 2025
CAST(hit_time as date)  = (select MAX(cast(hit_time as date)) from  mis.[dbo].[mis_automation_mv])
--and app_downloaded_history = 1 
and
--customer_type ='New'
customer_type ='Repeat'
and month(cast(date_modified as date)) =7--'2025-05-01' )--or disbursal_date  is null)
and (month(disbursal_date)= 7 or disbursal_date is null)
group by  cast(date_modified as date)
order by   cast(date_modified as date)


	"""
 
with engine.begin() as connection:
    connection.execute(text(sql_script))
query = "select * from #new"
df_Repeatv = pd.read_sql(query, engine)
print("repeat")

import pandas as pd

import pandas as pd

# Suppose 'totals' is your Series of summed values (e.g., journey_start, Eligible, etc.)
totals = df_Repeatv[['journey_start','Eligible','App_download','offer_select','KYC',
             'Submit','Submit_Apr','nach_complete','LA','disbursal','disbursed_amt']].sum()


import pandas as pd

# Convert the Series into a vertical one-column DataFrame
df_Repeatv = totals.reset_index(drop=True).to_frame(name='repeat vertical')
df_combined = pd.DataFrame()
df_combined = pd.concat(

    [df_newH.reset_index(drop=True), 

     df_newv.reset_index(drop=True),

     df_RepeatH.reset_index(drop=True), 

     df_Repeatv.reset_index(drop=True)],

    axis=1
)

df_combined.columns = ['NewH', 'NewV', 'RepeatH', 'RepeatV']

print(df_combined)



 # Replace with your actual data

# Sheet name to write to
sheet_name = 'Mtd data'

# Append to existing Excel file
with pd.ExcelWriter("MTD MV.xlsx", mode='a', engine='openpyxl', if_sheet_exists='replace') as writer:
    df_combined.to_excel(writer, sheet_name=sheet_name, index=False)

# df_combined.to_excel("MTD.xlsx", index=False)
# Out:
# new
# repeat
#          NewH       NewV    RepeatH     RepeatV
# 0     28933.0    45868.0     3213.0      5286.0
# 1     14244.0    28070.0     1263.0      2693.0
# 2       837.0     3068.0      413.0      1212.0
# 3       318.0     1106.0      174.0       463.0
# 4       141.0      588.0      131.0       343.0
# 5       126.0      531.0      127.0       330.0
# 6        85.0      266.0      100.0       233.0
# 7        60.0      184.0       90.0       189.0
# 8        57.0      169.0       87.0       182.0
# 9        56.0      166.0       85.0       179.0
# 10  1929000.0  5945000.0  4955000.0  10485000.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 259
#     256 sheet_name = 'Mtd data'
#     258 # Append to existing Excel file
# --> 259 with pd.ExcelWriter("MTD MV.xlsx", mode='a', engine='openpyxl', if_sheet_exists='replace') as writer:
# ...

# %%
# Out:
#        Campaign_Name    Surrogate_Key             ID                           Call_ID                     UUID      Direction        Description         Detailed_Description   Status  Blocked_Number_ID                   Recording_URL                    Service     Date       Time        End_Stamp      Broadcast_ID DTMF_Input  Call_Duration  Answered_Seconds  Minutes_Consumed  Charges Department_Name       Agent_Number       Agent_Number_With_Prefix    Agent_Name    Client_Number    DID_Number            Reason         Hangup_Cause                       Notes                        Contact_Details                   Missed_Agents                      AccountID   Agent_Ring_Time Agent_Hangup_Data Transfer_Missed_Agent Call_Hint Support_API_Call          Lead_ID          Is_Incoming_From_Broadcast Caller_ID_Num  SIP_Agent_IDs Custom_Status Voicemail_Recording   AWS_Call_Recording_Identifier              Circle                 Operator        Customer_Ring_Time  Call_Wait_Time  \
# ...
